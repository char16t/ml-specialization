# %% [markdown]
# ## Matplotlib

# %%
# %matplotlib inline

# %%
from matplotlib import pylab as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
import numpy as np
x = np.arange(-10, 10, 0.1)
y = x ** 3
plt.plot(x, y)
plt.show()
